# %%
#import packages
import pandas as pd
import numpy as np
import matplotlib as mpt
import matplotlib.pyplot as plt
import seaborn as sns 
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.graphics.gofplots import ProbPlot
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn import metrics
from sklearn.linear_model import LinearRegression

# %%
# Making a dataframe of current Pros that compete in the open male division (MPO)
# and of the tournament we want to predict.

mpo = pd.read_csv('MPO Stats.csv')
mh21 = pd.read_csv('Maple Hill 21.csv')

# %%
mpo
# Out:
#                  Name Division  Events  Wins   Win %  Podiums Podium %  \
# 0       Ezra Aderhold      MPO      69     7  10.14%       17   24.64%
# 1         Josh Anthon      MPO     221    50  22.62%      100   45.25%
# 2      Niklas Anttila      MPO      54    16  29.63%       29   53.70%
# 3          Dion Arlyn      MPO     205    37  18.05%       86   41.95%
# 4      Anthony Barela      MPO     157    29  18.47%       54   34.39%
# ..                ...      ...     ...   ...     ...      ...      ...
# 84  Knut Valen Håland      MPO      67    22  32.84%       37   55.22%
# 85        Dana Vicich      MPO     252    23   9.13%       69   27.38%
# 86        Casey White      MPO     124    17  13.71%       40   32.26%
# 87      Scott Withers      MPO     259   119  45.95%      173   66.80%
# 88    Richard Wysocki      MPO     354   117  33.05%      235   66.38%
#
#     Top 10 Top 10 % Rounds  Cash Prizes Cash Prize %  Throws Cash/Throw  \
# 0       31   44.93%    202           60       86.96%  11,795      $3.14
# 1      178   80.54%    851          210       95.02%  45,887      $3.38
# 2       48   88.89%    162           31       57.41%   9,440      $1.51
# 3      156   76.10%    618          165       80.49%  34,528      $1.16
# 4      101   64.33%    496           90       57.32%  28,802      $1.96
# ..     ...      ...    ...          ...          ...     ...        ...
# 84      55   82.09%    228           37       55.22%  13,025      $1.38
# 85     150   59.52%    705          173       68.65%  41,830      $1.13
# 86      68   54.84%    343           81       65.32%  20,129      $1.84
# 87     219   84.56%    721          249       96.14%  38,687      $2.50
# 88     321   90.68%  1,184          311       87.85%  64,803      $7.19
#
#    Total Earnings
# 0         $37,016
# 1        $155,170
# 2         $14,288
# 3         $39,987
# 4         $56,530
# ..            ...
# 84        $17,987
# 85        $47,345
# 86        $36,982
# 87        $96,666
# 88       $465,868
#
# [89 rows x 15 columns]

# %%
mh21.head(10)
# Out:
#    Place  Points                 Name  PDGA#  Rating  Par  Rd1  Rd2  Rd3  \
# 0      1    1440          Adam Hammes  57365    1038  -22   54   53   51
# 1      2    1430  Eagle Wynne McMahon  37817    1055  -19   51   52   58
# 2      2    1430      Richard Wysocki  38008    1055  -19   54   54   53
# 3      4    1410      Calvin Heimburg  45971    1049  -16   57   52   55
# 4      4    1410            Matt Bell  48950    1022  -16   58   52   54
# 5      4    1410         Matthew Orum  18330    1039  -16   55   53   56
# 6      7    1380       Andrew Marwede  75590    1025  -14   55   55   56
# 7      7    1380         Joel Freeman  69509    1030  -14   54   53   59
# 8      9    1360    Benjamin Callaway  39015    1022  -13   55   54   58
# 9      9    1360       Thomas Gilbert  85850    1022  -13   57   60   50
#
#    Total   Prize
# 0    158  $7,500
# 1    161  $3,350
# 2    161  $3,350
# 3    164  $2,097
# 4    164  $2,097
# 5    164  $2,097
# 6    166  $1,750
# 7    166  $1,750
# 8    167  $1,550
# 9    167  $1,550

# %%
# We want to try to predict who will be in the top 4.

mh21.loc[mh21.Place < 5]
# Out:
#    Place  Points                 Name  PDGA#  Rating  Par  Rd1  Rd2  Rd3  \
# 0      1    1440          Adam Hammes  57365    1038  -22   54   53   51
# 1      2    1430  Eagle Wynne McMahon  37817    1055  -19   51   52   58
# 2      2    1430      Richard Wysocki  38008    1055  -19   54   54   53
# 3      4    1410      Calvin Heimburg  45971    1049  -16   57   52   55
# 4      4    1410            Matt Bell  48950    1022  -16   58   52   54
# 5      4    1410         Matthew Orum  18330    1039  -16   55   53   56
#
#    Total   Prize
# 0    158  $7,500
# 1    161  $3,350
# 2    161  $3,350
# 3    164  $2,097
# 4    164  $2,097
# 5    164  $2,097

# %%
# The names in our dataframes weren't all the same, so I made a new column with the 
# first initial and last name in each dataframe.

mposplitnames = mpo['Name'].str.split(' ')
mpo['last_name'] = mposplitnames.str[-1]
mpo['first_name'] = mposplitnames.str[0]
mposplitfirst = mpo['first_name'].str.split('')
mpo['first_inital'] = mposplitfirst.str[1]
mpo['Name2']=mpo['first_inital'] + '.' + ' ' + mpo['last_name']
mpo = mpo.drop(['last_name', 'first_name', 'first_inital'], axis = 1)

mhsplitnames = mh21['Name'].str.split(' ')
mh21['last_name'] = mhsplitnames.str[-1]
mh21['first_name'] = mhsplitnames.str[0]
mh21splitfirst = mh21['first_name'].str.split('')
mh21['first_inital'] = mh21splitfirst.str[1]
mh21['Name2']=mh21['first_inital'] + '.' + ' ' + mh21['last_name']
mh21 = mh21.drop(['last_name', 'first_name', 'first_inital'], axis = 1)

# %%
# Making a new dataframe with just the competetors of the tournament.

mh21merged0 = mpo.merge(mh21.Name2, how = 'inner', on = 'Name2')

# %%
# Adding 'Place' to the previous datframe in order to get correlations.
mh21merged1 = mh21merged0.merge(mh21, how = 'inner', on = 'Name2')
mh21merged1.columns
# Out:
# Index(['Name_x', 'Division', 'Events', 'Wins', 'Win %', 'Podiums', 'Podium %',
#        'Top 10', 'Top 10 %', 'Rounds', 'Cash Prizes', 'Cash Prize %', 'Throws',
#        'Cash/Throw', 'Total Earnings', 'Name2', 'Place', 'Points', 'Name_y',
#        'PDGA#', 'Rating', 'Par', 'Rd1', 'Rd2', 'Rd3', 'Total', 'Prize'],
#       dtype='object')

# %%
mh21merged1.head(10)
# Out:
#               Name_x Division  Events  Wins   Win %  Podiums Podium %  Top 10  \
# 0      Ezra Aderhold      MPO      69     7  10.14%       17   24.64%      31
# 1       Gregg Barsby      MPO     431    74  17.17%      172   39.91%     286
# 2   Philo Brathwaite      MPO     337    38  11.28%      114   33.83%     196
# 3     Steve Brinster      MPO     408   107  26.23%      199   48.77%     313
# 4        Lance Brown      MPO     281    18   6.41%       67   23.84%     174
# 5  Benjamin Callaway      MPO     176    27  15.34%       53   30.11%     113
# 6           AJ Carey      MPO     228    20   8.77%       60   26.32%     125
# 7      Chris Clemons      MPO     172    30  17.44%       63   36.63%      99
# 8       James Conrad      MPO     251    31  12.35%       85   33.86%     182
# 9    Chris Dickerson      MPO     289   149  51.56%      211   73.01%     262
#
#   Top 10 % Rounds  ...  Points             Name_y   PDGA# Rating  Par Rd1  \
# 0   44.93%    202  ...    1200      Ezra Aderhold  121715   1024   -7  61
# 1   66.36%  1,495  ...    1330       Gregg Barsby   15857   1024  -11  57
# 2   58.16%  1,135  ...     990   Philo Brathwaite   26416   1021   -2  62
# 3   76.72%  1,360  ...    1050     Steve Brinster   10628   1019   -3  61
# 4   61.92%    859  ...    1280        Lance Brown   58644    995  -10  59
# 5   64.20%    528  ...    1360  Benjamin Callaway   39015   1022  -13  55
# 6   54.82%    662  ...     880           AJ Carey   61770   1009    E  60
# 7   57.56%    496  ...    1200      Chris Clemons   50401   1028   -7  58
# 8   72.51%    780  ...    1240       James Conrad   17295   1037   -9  60
# 9   90.66%    821  ...    1280    Chris Dickerson   62467   1045  -10  58
#
#    Rd2  Rd3 Total   Prize
# 0   60   52   173    $638
# 1   54   58   169  $1,110
# 2   59   57   178    $355
# 3   59   57   177    $405
# 4   57   54   170    $844
# 5   54   58   167  $1,550
# 6   63   57   180    $300
# 7   59   56   173    $638
# 8   53   58   171    $750
# 9   55   57   170    $844
#
# [10 rows x 27 columns]

# %%
# Removing unneeded columns.
mh21merged = mh21merged1.drop(['Points', 'Name_y', 'PDGA#', 'Rating', 'Par', 'Rd1', 'Rd2', 'Rd3', 'Total', 'Prize'], axis = 1)

# %%
correlations = mh21merged.corr().abs() # Absolute value to sort.
sort = correlations.unstack().sort_values(kind="quicksort", ascending = False).to_frame(name="corr").reset_index()
#unstack changes from matrix to pairs.
sort[sort.level_0 == 'Place']
# Out:
# C:\Users\march\AppData\Local\Temp\ipykernel_16964\4181554512.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlations = mh21merged.corr().abs() # Absolute value to sort.
#    level_0      level_1      corr
# 5    Place        Place  1.000000
# 27   Place         Wins  0.293430
# 29   Place      Podiums  0.290783
# 31   Place       Top 10  0.258999
# 33   Place  Cash Prizes  0.205880
# 35   Place       Events  0.133489

# %%
# Since Place is correlated the highest with these 4 variables, I'll sort by them.
# The ones at the top should be most likely to be in the top 4 of the tournament.
mh21merged0.sort_values(['Wins', 'Podiums', 'Top 10', 'Cash Prizes'], ascending=False).head(8)
# Out:
#                Name Division  Events  Wins   Win %  Podiums Podium %  Top 10  \
# 9   Chris Dickerson      MPO     289   149  51.56%      211   73.01%     262
# 25    Cale Leiviska      MPO     406   142  34.98%      257   63.30%     347
# 28      Paul McBeth      MPO     357   133  37.25%      244   68.35%     323
# 26   Nikko Locastro      MPO     446   122  27.35%      238   53.36%     355
# 39  Richard Wysocki      MPO     354   117  33.05%      235   66.38%     321
# 37    Paul Ulibarri      MPO     515   107  20.78%      234   45.44%     394
# 3    Steve Brinster      MPO     408   107  26.23%      199   48.77%     313
# 22    Emerson Keith      MPO     299    82  27.42%      153   51.17%     230
#
#    Top 10 % Rounds  Cash Prizes Cash Prize %  Throws Cash/Throw  \
# 9    90.66%    821          266       92.04%  43,666      $4.84
# 25   85.47%  1,246          399       98.28%  67,423      $4.19
# 28   90.48%  1,262          328       91.88%  68,064      $8.16
# 26   79.60%  1,522          408       91.48%  82,732      $4.17
# 39   90.68%  1,184          311       87.85%  64,803      $7.19
# 37   76.50%  1,649          488       94.76%  92,465      $3.28
# 3    76.72%  1,360          381       93.38%  75,767      $2.84
# 22   76.92%    723          228       76.25%  39,768      $2.73
#
#    Total Earnings         Name2
# 9        $211,171  C. Dickerson
# 25       $282,683   C. Leiviska
# 28       $555,450     P. McBeth
# 26       $345,334   N. Locastro
# 39       $465,868    R. Wysocki
# 37       $302,922   P. Ulibarri
# 3        $215,086   S. Brinster
# 22       $108,542      E. Keith

# %% [markdown]
# We can see that only 1 of the competitors who got top 4 in the tournament is on our sorted list.

# %%
# Attempting with another tournament.

worlds21 = pd.read_csv('Worlds 21.csv')

# %%
# We want to try to predict who will be in the top 4.

worlds21.loc[worlds21.Place < 5]
# Out:
#    Place  Points             Name  PDGA#  Rating  Par  Rd1  Rd2  Rd3  Rd4  \
# 0      1    3135     James Conrad  17295    1034  -39   50   56   52   54
# 1      2    3120      Paul McBeth  27523    1051  -39   51   55   52   53
# 2      3    3105    Nathan Sexton  18824    1033  -35   48   58   48   59
# 3      4    3090      Kevin Jones  41760    1033  -33   49   57   51   55
# 4      4    3090  Chris Dickerson  62467    1045  -33   53   54   53   54
#
#    Finals  Total    Prize
# 0      54    266  $16,500
# 1      55    266  $10,000
# 2      57    270   $8,500
# 3      60    272   $6,500
# 4      58    272   $6,500

# %%
worlds21splitnames = worlds21['Name'].str.split(' ')
worlds21['last_name'] = worlds21splitnames.str[-1]
worlds21['first_name'] = worlds21splitnames.str[0]
worlds21splitfirst = worlds21['first_name'].str.split('')
worlds21['first_inital'] = worlds21splitfirst.str[1]
worlds21['Name2']=worlds21['first_inital'] + '.' + ' ' + worlds21['last_name']
worlds21 = worlds21.drop(['last_name', 'first_name', 'first_inital'], axis = 1)

# %%
# Making a new dataframe with just the competetors of the tournament.

worlds21merged0 = mpo.merge(worlds21.Name2, how = 'inner', on = 'Name2')

# %%
# Adding 'Place' to the previous datframe in order to get correlations.
worlds21merged1 = worlds21merged0.merge(worlds21, how = 'inner', on = 'Name2')
worlds21merged1.columns
# Out:
# Index(['Name_x', 'Division', 'Events', 'Wins', 'Win %', 'Podiums', 'Podium %',
#        'Top 10', 'Top 10 %', 'Rounds', 'Cash Prizes', 'Cash Prize %', 'Throws',
#        'Cash/Throw', 'Total Earnings', 'Name2', 'Place', 'Points', 'Name_y',
#        'PDGA#', 'Rating', 'Par', 'Rd1', 'Rd2', 'Rd3', 'Rd4', 'Finals', 'Total',
#        'Prize'],
#       dtype='object')

# %%
# Removing unneeded columns.
worlds21merged = worlds21merged1.drop(['Points', 'Name_y', 'PDGA#', 'Rating', 'Par', 'Rd1', 'Rd2', 'Rd3', 'Rd4', 'Finals', 'Total', 'Prize'], axis = 1)

# %%
correlations = worlds21merged.corr().abs() # Absolute value to sort.
sort = correlations.unstack().sort_values(kind="quicksort", ascending = False).to_frame(name="corr").reset_index()
#unstack changes from matrix to pairs.
sort[sort.level_0 == 'Place']
# Out:
# C:\Users\march\AppData\Local\Temp\ipykernel_16964\2592611438.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlations = worlds21merged.corr().abs() # Absolute value to sort.
#    level_0      level_1      corr
# 5    Place        Place  1.000000
# 27   Place         Wins  0.410830
# 29   Place      Podiums  0.374304
# 31   Place       Top 10  0.314207
# 33   Place  Cash Prizes  0.234412
# 35   Place       Events  0.168963

# %%
# We see the same 4 variables.
worlds21merged0.sort_values(['Wins', 'Podiums', 'Top 10', 'Cash Prizes'], ascending=False).head(8)
# Out:
#                Name Division  Events  Wins   Win %  Podiums Podium %  Top 10  \
# 10  Chris Dickerson      MPO     289   149  51.56%      211   73.01%     262
# 29    Cale Leiviska      MPO     406   142  34.98%      257   63.30%     347
# 32      Paul McBeth      MPO     357   133  37.25%      244   68.35%     323
# 31   Nikko Locastro      MPO     446   122  27.35%      238   53.36%     355
# 50    Scott Withers      MPO     259   119  45.95%      173   66.80%     219
# 51  Richard Wysocki      MPO     354   117  33.05%      235   66.38%     321
# 48    Paul Ulibarri      MPO     515   107  20.78%      234   45.44%     394
# 44      Nate Sexton      MPO     313    89  28.43%      174   55.59%     255
#
#    Top 10 % Rounds  Cash Prizes Cash Prize %  Throws Cash/Throw  \
# 10   90.66%    821          266       92.04%  43,666      $4.84
# 29   85.47%  1,246          399       98.28%  67,423      $4.19
# 32   90.48%  1,262          328       91.88%  68,064      $8.16
# 31   79.60%  1,522          408       91.48%  82,732      $4.17
# 50   84.56%    721          249       96.14%  38,687      $2.50
# 51   90.68%  1,184          311       87.85%  64,803      $7.19
# 48   76.50%  1,649          488       94.76%  92,465      $3.28
# 44   81.47%  1,075          294       93.93%  58,382      $3.52
#
#    Total Earnings         Name2
# 10       $211,171  C. Dickerson
# 29       $282,683   C. Leiviska
# 32       $555,450     P. McBeth
# 31       $345,334   N. Locastro
# 50        $96,666    S. Withers
# 51       $465,868    R. Wysocki
# 48       $302,922   P. Ulibarri
# 44       $205,465     N. Sexton

# %% [markdown]
# Here we got 3 of the 5 finalists.

# %%
# Let's try one more tournament.
gmc = pd.read_csv('GMC 21.csv')

# %%
# We want to try to predict who will be in the top 4.

gmc.loc[gmc.Place < 5]
# Out:
#    Place  Points             Name  PDGA#  Rating  Par  Rd1  Rd2  Rd3  Finals  \
# 0      1    1340  Chris Dickerson  62467    1045  -41   52   51   48      56
# 1      2    1330  Richard Wysocki  38008    1055  -38   53   52   51      54
# 2      3    1320  Andrew Presnell  63765    1027  -30   52   54   51      61
# 3      3    1320      Paul McBeth  27523    1053  -30   53   58   53      54
#
#    Total   Prize
# 0    207  $6,000
# 1    210  $3,500
# 2    218  $2,165
# 3    218  $2,165

# %%
gmcsplitnames = gmc['Name'].str.split(' ')
gmc['last_name'] = gmcsplitnames.str[-1]
gmc['first_name'] = gmcsplitnames.str[0]
gmcsplitfirst = gmc['first_name'].str.split('')
gmc['first_inital'] = gmcsplitfirst.str[1]
gmc['Name2']=gmc['first_inital'] + '.' + ' ' + gmc['last_name']
gmc = gmc.drop(['last_name', 'first_name', 'first_inital'], axis = 1)

# %%
# Making a new dataframe with just the competetors of the tournament.

gmcmerged0 = mpo.merge(gmc.Name2, how = 'inner', on = 'Name2')

# %%
# Adding 'Place' to the previous datframe in order to get correlations.
gmcmerged1 = gmcmerged0.merge(gmc, how = 'inner', on = 'Name2')
gmcmerged1.columns
# Out:
# Index(['Name_x', 'Division', 'Events', 'Wins', 'Win %', 'Podiums', 'Podium %',
#        'Top 10', 'Top 10 %', 'Rounds', 'Cash Prizes', 'Cash Prize %', 'Throws',
#        'Cash/Throw', 'Total Earnings', 'Name2', 'Place', 'Points', 'Name_y',
#        'PDGA#', 'Rating', 'Par', 'Rd1', 'Rd2', 'Rd3', 'Finals', 'Total',
#        'Prize'],
#       dtype='object')

# %%
# Removing unneeded columns.
gmcmerged = gmcmerged1.drop(['Points', 'Name_y', 'PDGA#', 'Rating', 'Par', 'Rd1', 'Rd2', 'Rd3', 'Finals', 'Total', 'Prize'], axis = 1)

# %%
correlations = gmcmerged.corr().abs() # Absolute value to sort.
sort = correlations.unstack().sort_values(kind="quicksort", ascending = False).to_frame(name="corr").reset_index()
#unstack changes from matrix to pairs.
sort[sort.level_0 == 'Place']
# Out:
# C:\Users\march\AppData\Local\Temp\ipykernel_16964\442745461.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlations = gmcmerged.corr().abs() # Absolute value to sort.
#    level_0      level_1      corr
# 5    Place        Place  1.000000
# 27   Place         Wins  0.383278
# 29   Place      Podiums  0.359664
# 31   Place       Top 10  0.318055
# 33   Place  Cash Prizes  0.248087
# 35   Place       Events  0.217677

# %%
# Again, we see the same 4 variables.
gmcmerged0.sort_values(['Wins', 'Podiums', 'Top 10', 'Cash Prizes'], ascending=False).head(8)
# Out:
#                Name Division  Events  Wins   Win %  Podiums Podium %  Top 10  \
# 7   Chris Dickerson      MPO     289   149  51.56%      211   73.01%     262
# 22    Cale Leiviska      MPO     406   142  34.98%      257   63.30%     347
# 26      Paul McBeth      MPO     357   133  37.25%      244   68.35%     323
# 24   Nikko Locastro      MPO     446   122  27.35%      238   53.36%     355
# 35  Richard Wysocki      MPO     354   117  33.05%      235   66.38%     321
# 33    Paul Ulibarri      MPO     515   107  20.78%      234   45.44%     394
# 21    Jeremy Koling      MPO     388    73  18.81%      157   40.46%     281
# 30        Matt Orum      MPO     290    71  24.48%      136   46.90%     218
#
#    Top 10 % Rounds  Cash Prizes Cash Prize %  Throws Cash/Throw  \
# 7    90.66%    821          266       92.04%  43,666      $4.84
# 22   85.47%  1,246          399       98.28%  67,423      $4.19
# 26   90.48%  1,262          328       91.88%  68,064      $8.16
# 24   79.60%  1,522          408       91.48%  82,732      $4.17
# 35   90.68%  1,184          311       87.85%  64,803      $7.19
# 33   76.50%  1,649          488       94.76%  92,465      $3.28
# 21   72.42%  1,314          345       88.92%  73,429      $2.86
# 30   75.17%  1,015          266       91.72%  55,254      $3.68
#
#    Total Earnings         Name2
# 7        $211,171  C. Dickerson
# 22       $282,683   C. Leiviska
# 26       $555,450     P. McBeth
# 24       $345,334   N. Locastro
# 35       $465,868    R. Wysocki
# 33       $302,922   P. Ulibarri
# 21       $209,777     J. Koling
# 30       $203,174       M. Orum

# %% [markdown]
# This time we got 3 of the top 4, but also first place.
